# %% [markdown]
# # Casos confirmados em cada concelho de Portugal

# %%
import pandas as pd
import os as os

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
user = os.getenv('postgres')
password = os.getenv('natureza123')
connection_string = "postgresql://postgres:natureza123@localhost/miebiom".format(user=user, password=password)
# %sql $connection_string
# Out:
# 'Connected: postgres@miebiom'

# %%
# %sql SELECT * FROM "confirmados_concelho" WHERE mais_recente IS NULL
# Out:
#  * postgresql://postgres:***@localhost/miebiom
# 82 rows affected.
# [(6, 6, '1209', 'GAVIÃO', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None),
# ...

# %%
# %sql select count(*) FROM "confirmados_concelho" WHERE mais_recente is NULL
# Out:
#  * postgresql://postgres:***@localhost/miebiom
# 1 rows affected.
# [(82,)]

# %%
result = %sql SELECT concelho, mais_recente FROM confirmados_concelho WHERE mais_recente > 500
print(result)
# Out:
#  * postgresql://postgres:***@localhost/miebiom
# 16 rows affected.
# +-------------------+--------------+
# |      concelho     | mais_recente |
# +-------------------+--------------+
# |      ODIVELAS     |     581      |
# |      CASCAIS      |     579      |
# |     MATOSINHOS    |     1281     |
# |        OVAR       |     662      |
# |       BRAGA       |     1225     |
# |       LOURES      |     1089     |
# |       SINTRA      |     1355     |
# |       LISBOA      |     2447     |
# |      AMADORA      |     890      |
# |      GONDOMAR     |     1083     |
# |        MAIA       |     944      |
# |     GUIMARÃES     |     720      |
# |      VALONGO      |     757      |
# |       PORTO       |     1358     |
# | VILA NOVA DE GAIA |     1578     |
# |      COIMBRA      |     592      |
# +-------------------+--------------+

# %%
# %matplotlib notebook
result.pie()
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.patches.Wedge at 0x1f75d7ddd30>,
# ...
#  [Text(1.093769369397525, 0.11691264502927233, 'ODIVELAS'),
#   Text(1.0444735842061328, 0.34507235747824627, 'CASCAIS'),
#   Text(0.8689987259690085, 0.6744191680729725, 'MATOSINHOS'),
#   Text(0.5793526360315325, 0.9350671222555709, 'OVAR'),
#   Text(0.2280652048764497, 1.0760977011055564, 'BRAGA'),
#   Text(-0.2349633812622538, 1.074612585756285, 'LOURES'),
#   Text(-0.6772028963660215, 0.8668311468524142, 'SINTRA'),
#   Text(-1.0756568083542828, 0.230135678765979, 'LISBOA'),
#   Text(-1.0128103097737768, -0.4292030713030213, 'AMADORA'),
#   Text(-0.7954663485751905, -0.7597587039872947, 'GONDOMAR'),
#   Text(-0.4653926594736651, -0.9966993892383147, 'MAIA'),
#   Text(-0.14463646281102654, -1.0904495832570686, 'GUIMARÃES'),
#   Text(0.15222745354598133, -1.0894158078469882, 'VALONGO'),
#   Text(0.5527330899245673, -0.9510447577808525, 'PORTO'),
# ...

# %%
df = result.DataFrame()    
df.plot.pie(y='mais_recente', labels=df['concelho'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df2 = result.DataFrame()
df2.plot.bar(x='concelho', y='mais_recente', figsize=(8,6));
# Out:
# <img src="data:image/png;base64,..." width="800">
