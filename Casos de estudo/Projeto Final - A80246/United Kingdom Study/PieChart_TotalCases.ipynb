# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('covid-19-cases-UK.csv')
data = data.set_index('Date')
data.head()
# Out:
#            Country   AreaCode              Area  TotalCases
# Date
# 2020-01-08   Wales  W11000028     Aneurin Bevan         0.0
# 2020-01-08   Wales  W11000023   Betsi Cadwaladr         0.0
# 2020-01-08   Wales  W11000029  Cardiff and Vale         0.0
# 2020-01-08   Wales  W11000030           Cwm Taf         0.0
# 2020-01-08   Wales  W11000025         Hywel Dda         0.0

# %%
data = data.groupby('Country').agg({'TotalCases':'sum'})
data.plot.pie(y='TotalCases', figsize = (8,8), colormap='Pastel1')
